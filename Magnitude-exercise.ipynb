# %% [markdown]
# # Pick and calculate magnitude for an earthquake
#
# This is a simple exercise to get students used to thinking about earthquake magnitudes. To run this exercise,
# select an event (use the [GeoNet QuakeSearch](https://quakesearch.geonet.org.nz/) tool to find the eventid of an earthquake in the GeoNet catalogue that you are interested in, run the cell below, and input the stations you want to plot. A plot will be made that you can supply to students. They can then measure the maximum amplitude for each station and compute the magnitudes using the local magnitude relation below:
#
#
#
# Ideally you will get to see the amplitude decay with distance, you might also see different amplitudes for stations are similar distances, but different azimuths due to the radiation pattern of the earthquake, or due to differing site conditions.

# %%
# %matplotlib ipympl

from tools.get_waveforms import get_and_plot_waveforms

fig = get_and_plot_waveforms(eventid="2023p853474")
# Out:
# Available stations:
# AKCZ ANWZ ARHZ AWAZ BFZ BHHZ BHW BKZ BSWZ CAW CKHZ CMWZ CNGZ COVZ CPFS CPWZ CRSZ CTZ CVZ DREZ DSZ DUWZ DVHS DVHZ EKTS ETVZ FEGZ FOZ FWVZ GRRZ HATZ HAZ HIZ HNCZ HOCS HOWZ INZ KAHZ KATZ KHEZ KHZ KIRS KIW KPRZ KRHZ KRVZ KUTZ KWHZ LBZ LREZ LTZ MAVS MAVZ MBAZ MCHZ MHGZ MKAZ MNGS MNMZ MOVZ MRHZ MRZ MSWZ MTVZ MTW MWOZ MWZ MXZ NBEZ NBSS NGZ NMEZ NMHZ NNZ NOVZ NTVZ OAHZ ODZ OGWZ OHWZ OKCZ OMRZ OTKS OTVZ PAWZ PKE PKGZ PKVZ PLWZ PNBS PNHZ PNMS PNRS POIZ POWZ PREZ PRGZ PRHZ PRRZ PRWZ PUZ PWES PWZ PXZ QRZ RAGZ RAHZ RATZ RITZ RRRZ RTZ RUGZ SNGZ SNVZ TAIS TARZ TCW THSZ THZ TIWZ TKNZ TLZ TMVZ TMWZ TOZ TRMS TRVZ TRWZ TSZ TUVZ TUWZ TWGZ TWVZ URZ VRZ WAKS WATZ WAZ WCZ WDPS WEL WHHZ WHRZ WHTZ WHVZ WIAZ WMGZ WPHZ WPRZ WPWS WRCS WTVZ
# Type the code(s) of the stations you want to plot. Separate stations with spaces (e.g. FOZ WVZ). Press return when done
# Enter stations: BHW PRHZ WEL
# You selected: BHW PRHZ WEL
# ...
